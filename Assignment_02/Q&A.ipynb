# %%
#1.Review the main points of this lesson.
1. How to Github and Why do we use Jupyter and Pycharm;
Ans:
    Github：代码分享
    Jupyter：代码展示、渲染
    Pycharm：代码Debug

2. What's the Probability Model?
Ans:
    描述不同随机变量之间的关系

3. Can you came up with some sceneraies at which we could use Probability Model?
Ans:
    通过描述不同随机变量之间的关系，可以得到某句话的发生概率（即组成这句话的词汇们，以此固定顺序排列出现的概率），以及不同句子之间的概率。

4. Why do we use probability and what's the difficult points for programming based on parsing and pattern match?
Ans:
    因为语言是具有创造性的，在不同的语境和情况下，所表达的含义不同。且在很多情况下，无法100%获得准确的输入，因此需要有数据支撑的概率模型来
    进行补强。
    基于语法和模式的匹配，适应性较差，对语料库的设计和回答逻辑要求过高。

5. What's the Language Model;
Ans:
    语言模型通常表现某句话的发生概率分布（即组成这句话的词汇们，以此固定顺序排列出现的概率），以及不同句子之间的概率。

6. Can you came up with some sceneraies at which we could use Language Model?
Ans:
    

7. What's the 1-gram language model;
Ans:
    就是句子中每个词都是独立的，它出现的概率与其他词汇无关。

8. What's the disadvantages and advantages of 1-gram language model;
Ans:
    优势：简单，计算量小
    劣势：与实际情况相差较远

9. What't the 2-gram models;
Ans:
    句子中每个词都与它前边（或后边）紧靠着的词有关，当前边的词出现的时候会对后边出现的词有影响。

10. what's the web crawler, and can you implement a simple crawler?
Ans:
    按照一定的规则抓取特定网络信息的程序或者脚本。

11. There may be some issues to make our crwaler programming difficult, what are these, and how do we solve them?
Ans:
    

12. What't the Regular Expression and how to use?¶
Ans:
    正则表达式是对字符串操作的一种逻辑公式，就是用事先定义好的一些特定字符、及这些特定字符的组合，组成一个“规则字符串”，这个“规则字符串”
    用来表达对字符串的一种过滤逻辑。
    正则表达式通常被用来检索、替换那些符合某个模式(规则)的文本。
    
#2.Using Wikipedia dataset to finish the language model.
1. If we need to solve following problems, how can language model help us?
Ans:
    Voice Recognization:因为语音识别很难100%准确地识别语音，因此需要语言模型来获得与识别的句子匹配的概率。
    Sogou pinyin input:通过多次输入，构建常用词汇语料库，将概率大的词汇放在前边，方便使用。
    Auto correction in search engine:返回更加常用的搜索结果。
    Abnormal Detection:增加异常检测准确率
    
2. Compared to the previous learned parsing and pattern match problems. What's the advantage and disavantage of Probability Based Methods?
Ans:
    
    

    
#(Optional) How to solve OOV problem?
1. How did you solve this problem in your programming task?
Ans:


2.: Read about the 'Turing-Good Estimator', can explain the main points about this method, and may implement this method in your programming task
Ans:
